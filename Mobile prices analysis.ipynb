# %%
# importing the module
import pandas as pd
data=pd.read_csv("Mobile_Specification_data.csv")
data
# Out:
#       Unnamed: 0                            Name     Brand  \
# 0              0  OnePlus 7T Pro McLaren Edition   OnePlus
# 1              1                   Realme X2 Pro    Realme
# 2              2               iPhone 11 Pro Max     Apple
# 3              3                       iPhone 11     Apple
# 4              4                    LG G8X ThinQ        LG
# ...          ...                             ...       ...
# 1354        1354                   Intex Aqua A2     Intex
# 1355        1355     Videocon Infinium Z51 Nova+  Videocon
# 1356        1356                   Intex Aqua Y4     Intex
# 1357        1357                 iBall Andi4 B20     iBall
# 1358        1358             iBall Andi Avonte 5     iBall
#
#                        Model  Battery capacity (mAh)  Screen size (inches)  \
# 0     7T Pro McLaren Edition                    4085                  6.67
# 1                     X2 Pro                    4000                  6.50
# ...

# %%
upd_data=data[(data["Brand"]=="Apple")
      |(data["Brand"]=="Samsung")
      |(data["Brand"]=="OnePlus")
      |(data["Brand"]=="Realme")
      |(data["Brand"]=="Infinix")
      |(data["Brand"]=="Techno")
      |(data["Brand"]=="Oppo")
      |(data["Brand"]=="Vivo")
      |(data["Brand"]=="Xiaomi")
      |(data["Brand"]=="Nokia")]

upd_data
# Out:
#       Unnamed: 0                            Name    Brand  \
# 0              0  OnePlus 7T Pro McLaren Edition  OnePlus
# 1              1                   Realme X2 Pro   Realme
# 2              2               iPhone 11 Pro Max    Apple
# 3              3                       iPhone 11    Apple
# 5              5                      OnePlus 7T  OnePlus
# ...          ...                             ...      ...
# 1282        1282                      Samsung Z3  Samsung
# 1294        1294                       Vivo Y15S     Vivo
# 1295        1295           Samsung Galaxy J1 Ace  Samsung
# 1296        1296                       Vivo Y27L     Vivo
# 1350        1350                         Vivo V1     Vivo
#
#                        Model  Battery capacity (mAh)  Screen size (inches)  \
# 0     7T Pro McLaren Edition                    4085                  6.67
# 1                     X2 Pro                    4000                  6.50
# ...

# %%
data.head()
# Out:
#    Unnamed: 0                            Name    Brand  \
# 0           0  OnePlus 7T Pro McLaren Edition  OnePlus
# 1           1                   Realme X2 Pro   Realme
# 2           2               iPhone 11 Pro Max    Apple
# 3           3                       iPhone 11    Apple
# 4           4                    LG G8X ThinQ       LG
#
#                     Model  Battery capacity (mAh)  Screen size (inches)  \
# 0  7T Pro McLaren Edition                    4085                  6.67
# 1                  X2 Pro                    4000                  6.50
# 2       iPhone 11 Pro Max                    3969                  6.50
# 3               iPhone 11                    3110                  6.10
# 4               G8X ThinQ                    4000                  6.40
#
#   Touchscreen  Resolution x  Resolution y  Processor  ...  Rear camera  \
# 0         Yes          1440          3120          8  ...         48.0
# ...

# %%
data.tail()
# Out:
#       Unnamed: 0                         Name     Brand               Model  \
# 1354        1354                Intex Aqua A2     Intex             Aqua A2
# 1355        1355  Videocon Infinium Z51 Nova+  Videocon  Infinium Z51 Nova+
# 1356        1356                Intex Aqua Y4     Intex             Aqua Y4
# 1357        1357              iBall Andi4 B20     iBall           Andi4 B20
# 1358        1358          iBall Andi Avonte 5     iBall       Andi Avonte 5
#
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 1354                    1500                   4.0         Yes           480
# 1355                    2000                   5.0         Yes           480
# 1356                    1700                   4.5         Yes           480
# 1357                    1250                   4.0         Yes           480
# 1358                    2150                   5.0         Yes           480
#
# ...

# %%
data.sample()
# Out:
#       Unnamed: 0             Name   Brand     Model  Battery capacity (mAh)  \
# 1308        1308  Lenovo Vibe P1m  Lenovo  Vibe P1m                    3900
#
#       Screen size (inches) Touchscreen  Resolution x  Resolution y  Processor  \
# 1308                   5.0         Yes           720          1280          4
#
#       ...  Rear camera  Front camera  Operating system  Wi-Fi Bluetooth  GPS  \
# 1308  ...          8.0           5.0           Android    Yes       Yes  Yes
#
#      Number of SIMs   3G  4G/ LTE Price
# 1308              2  Yes      Yes  6999
#
# [1 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1359 non-null   int64
#  1   Name                    1359 non-null   object
#  2   Brand                   1359 non-null   object
#  3   Model                   1359 non-null   object
#  4   Battery capacity (mAh)  1359 non-null   int64
#  5   Screen size (inches)    1359 non-null   float64
#  6   Touchscreen             1359 non-null   object
#  7   Resolution x            1359 non-null   int64
#  8   Resolution y            1359 non-null   int64
#  9   Processor               1359 non-null   int64
#  10  RAM (MB)                1359 non-null   int64
#  11  Internal storage (GB)   1359 non-null   float64
#  12  Rear camera             1359 non-null   float64
#  13  Front camera            1359 non-null   float64
# ...

# %%
data.size
# Out:
# 29898

# %%
data.shape
# Out:
# (1359, 22)

# %%
data.isnull()
# Out:
#       Unnamed: 0   Name  Brand  Model  Battery capacity (mAh)  \
# 0          False  False  False  False                   False
# 1          False  False  False  False                   False
# 2          False  False  False  False                   False
# 3          False  False  False  False                   False
# 4          False  False  False  False                   False
# ...          ...    ...    ...    ...                     ...
# 1354       False  False  False  False                   False
# 1355       False  False  False  False                   False
# 1356       False  False  False  False                   False
# 1357       False  False  False  False                   False
# 1358       False  False  False  False                   False
#
#       Screen size (inches)  Touchscreen  Resolution x  Resolution y  \
# 0                    False        False         False         False
# 1                    False        False         False         False
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Name                      0
# Brand                     0
# Model                     0
# Battery capacity (mAh)    0
# Screen size (inches)      0
# Touchscreen               0
# Resolution x              0
# Resolution y              0
# Processor                 0
# RAM (MB)                  0
# Internal storage (GB)     0
# Rear camera               0
# Front camera              0
# Operating system          0
# Wi-Fi                     0
# Bluetooth                 0
# GPS                       0
# Number of SIMs            0
# 3G                        0
# 4G/ LTE                   0
# Price                     0
# dtype: int64

# %%
# 5. How does the data look mathematically?
data.describe()# mathematically summary of data
# Out:
#         Unnamed: 0  Battery capacity (mAh)  Screen size (inches)  \
# count  1359.000000             1359.000000           1359.000000
# mean    679.000000             2938.489330              5.291310
# std     392.453819              873.514133              0.671357
# min       0.000000             1010.000000              2.400000
# 25%     339.500000             2300.000000              5.000000
# 50%     679.000000             3000.000000              5.200000
# 75%    1018.500000             3500.000000              5.700000
# max    1358.000000             6000.000000              7.300000
#
#        Resolution x  Resolution y    Processor      RAM (MB)  \
# count   1359.000000   1359.000000  1359.000000   1359.000000
# mean     811.543046   1490.777778     5.551141   2488.777778
# std      270.707271    557.780120     2.196562   1664.440386
# min      240.000000    320.000000     1.000000     64.000000
# 25%      720.000000   1280.000000     4.000000   1000.000000
# ...

# %%
# 6. Are there duplicate values?
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1354    False
# 1355    False
# 1356    False
# 1357    False
# 1358    False
# Length: 1359, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
# 7. How is the correlation between cols?
data.corr
# Out:
# <bound method DataFrame.corr of       Unnamed: 0                            Name     Brand  \
# 0              0  OnePlus 7T Pro McLaren Edition   OnePlus
# 1              1                   Realme X2 Pro    Realme
# 2              2               iPhone 11 Pro Max     Apple
# 3              3                       iPhone 11     Apple
# 4              4                    LG G8X ThinQ        LG
# ...          ...                             ...       ...
# 1354        1354                   Intex Aqua A2     Intex
# 1355        1355     Videocon Infinium Z51 Nova+  Videocon
# 1356        1356                   Intex Aqua Y4     Intex
# 1357        1357                 iBall Andi4 B20     iBall
# 1358        1358             iBall Andi Avonte 5     iBall
#
#                        Model  Battery capacity (mAh)  Screen size (inches)  \
# 0     7T Pro McLaren Edition                    4085                  6.67
# ...

# %%
data.mode()
# Out:
#       Unnamed: 0            Name  Brand Model  Battery capacity (mAh)  \
# 0              0         10.or D  Intex    V5                  3000.0
# 1              1        10.or D2    NaN   NaN                     NaN
# 2              2         10.or E    NaN   NaN                     NaN
# 3              3         10.or G    NaN   NaN                     NaN
# 4              4        10.or G2    NaN   NaN                     NaN
# ...          ...             ...    ...   ...                     ...
# 1354        1354  iVoomi i2 Lite    NaN   NaN                     NaN
# 1355        1355     iVoomi iPro    NaN   NaN                     NaN
# 1356        1356    iVoomi iV505    NaN   NaN                     NaN
# 1357        1357   mPhone 7 Plus    NaN   NaN                     NaN
# 1358        1358        mPhone 8    NaN   NaN                     NaN
#
#       Screen size (inches) Touchscreen  Resolution x  Resolution y  Processor  \
# ...

# %%
data.corr(numeric_only=True)
# Out:
#                         Unnamed: 0  Battery capacity (mAh)  \
# Unnamed: 0                1.000000               -0.417557
# Battery capacity (mAh)   -0.417557                1.000000
# Screen size (inches)     -0.448372                0.746886
# Resolution x             -0.465304                0.495362
# Resolution y             -0.546045                0.573969
# Processor                -0.424670                0.538017
# RAM (MB)                 -0.502721                0.600969
# Internal storage (GB)    -0.444736                0.483489
# Rear camera              -0.424549                0.499756
# Front camera             -0.443835                0.540250
# Number of SIMs            0.097866                0.040151
# Price                    -0.359745                0.297525
#
#                         Screen size (inches)  Resolution x  Resolution y  \
# Unnamed: 0                         -0.448372     -0.465304     -0.546045
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Brand', 'Model', 'Battery capacity (mAh)',
#        'Screen size (inches)', 'Touchscreen', 'Resolution x', 'Resolution y',
#        'Processor', 'RAM (MB)', 'Internal storage (GB)', 'Rear camera',
#        'Front camera', 'Operating system', 'Wi-Fi', 'Bluetooth', 'GPS',
#        'Number of SIMs', '3G', '4G/ LTE', 'Price'],
#       dtype='object')

# %% [markdown]
# # WORKING ON COLUMNS = "Battery capacity (mAh)","Screen size (inches)","Touchscreen"

# %%
selected_columns = ["Battery capacity (mAh)","Screen size (inches)","Touchscreen"]
selected_data = data[selected_columns]
print(selected_data.describe())
# Out:
#        Battery capacity (mAh)  Screen size (inches)
# count             1359.000000           1359.000000
# mean              2938.489330              5.291310
# std                873.514133              0.671357
# min               1010.000000              2.400000
# 25%               2300.000000              5.000000
# 50%               3000.000000              5.200000
# 75%               3500.000000              5.700000
# max               6000.000000              7.300000

# %%
import pandas as pd
selected_columns = ["Battery capacity (mAh)","Screen size (inches)","Touchscreen"]
selected_data = data[selected_columns]
print(selected_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Battery capacity (mAh)  1359 non-null   int64
#  1   Screen size (inches)    1359 non-null   float64
#  2   Touchscreen             1359 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 32.0+ KB
# None

# %%
import pandas as pd
selected_columns = ["Battery capacity (mAh)","Screen size (inches)","Touchscreen"]
selected_data= data[selected_columns]
print(selected_data.nunique())
# Out:
# Battery capacity (mAh)    165
# Screen size (inches)       80
# Touchscreen                 2
# dtype: int64

# %%
data["Battery capacity (mAh)"].value_counts()
# Out:
# Battery capacity (mAh)
# 3000    182
# 4000    145
# 2000    115
# 2500     91
# 5000     49
#        ...
# 3250      1
# 3550      1
# 3730      1
# 5100      1
# 1960      1
# Name: count, Length: 165, dtype: int64

# %%
data["Screen size (inches)"].value_counts()
# Out:
# Screen size (inches)
# 5.00    404
# 5.50    251
# 5.20     82
# 4.50     80
# 4.00     71
#        ...
# 2.40      1
# 6.01      1
# 6.23      1
# 6.42      1
# 7.00      1
# Name: count, Length: 80, dtype: int64

# %%
data["Touchscreen"].value_counts()
# Out:
# Touchscreen
# Yes    1342
# No       17
# Name: count, dtype: int64

# %%
selected_columns = ["Battery capacity (mAh)","Screen size (inches)","Touchscreen"]
min_values = data[["Battery capacity (mAh)","Screen size (inches)","Touchscreen"]].min()
print("Min values:")
print(min_values)
# Out:
# Min values:
# Battery capacity (mAh)    1010
# Screen size (inches)       2.4
# Touchscreen                 No
# dtype: object

# %%
max_values = data[["Battery capacity (mAh)","Screen size (inches)","Touchscreen"]].max()
print("Maximum values:")
print(max_values)
# Out:
# Maximum values:
# Battery capacity (mAh)    6000
# Screen size (inches)       7.3
# Touchscreen                Yes
# dtype: object

# %%
data.describe = data[["Screen size (inches)","Touchscreen"]].describe()

print("describe")
print(data.describe)
# Out:
# describe
#        Screen size (inches)
# count           1359.000000
# mean               5.291310
# std                0.671357
# min                2.400000
# 25%                5.000000
# 50%                5.200000
# 75%                5.700000
# max                7.300000

# %%
data.describe = data[["Battery capacity (mAh)","Screen size (inches)","Touchscreen"]].describe()
print("describe")
print(data.describe)
# Out:
# describe
#        Battery capacity (mAh)  Screen size (inches)
# count             1359.000000           1359.000000
# mean              2938.489330              5.291310
# std                873.514133              0.671357
# min               1010.000000              2.400000
# 25%               2300.000000              5.000000
# 50%               3000.000000              5.200000
# 75%               3500.000000              5.700000
# max               6000.000000              7.300000

# %%
data.sort_values(by="Battery capacity (mAh)")
# Out:
#       Unnamed: 0                   Name    Brand          Model  \
# 443          443         Nokia Asha 502    Nokia       Asha 502
# 908          908             Samsung Z4  Samsung             Z4
# 585          585  Samsung Galaxy Pocket  Samsung  Galaxy Pocket
# 1166        1166               Lava A52     Lava            A52
# 587          587         Nokia Asha 501    Nokia       Asha 501
# ...          ...                    ...      ...            ...
# 358          358              Lenovo P2   Lenovo             P2
# 157          157        Xiaomi Mi Max 2   Xiaomi       Mi Max 2
# 621          621      Tecno Spark Power    Tecno    Spark Power
# 8              8       Asus ROG Phone 2     Asus    ROG Phone 2
# 78            78    Samsung Galaxy M30s  Samsung    Galaxy M30s
#
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 443                     1010                  3.00         Yes           240
# ...

# %%
# we cant find out corr in this laibrary beacuse 2 of them is in string
selected_columns = ["Battery capacity (mAh)","Screen size (inches)"]
correlation_matrix = data[selected_columns].corr()
print(correlation_matrix)
# Out:
#                         Battery capacity (mAh)  Screen size (inches)
# Battery capacity (mAh)                1.000000              0.746886
# Screen size (inches)                  0.746886              1.000000
